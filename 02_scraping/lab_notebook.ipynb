# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it. I look at used cars below.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %%
furniture_url = 'https://charlottesville.craigslist.org/search/fua?purveyor=owner#search=1~gallery~0~0'
furniture_raw = requests.get(furniture_url,headers=header) # Get page

# %% [markdown]
# I am looking at the furniture data. I would like to look at the price and type of furniture to see which types of furniture are the most expensive.

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's below.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %%
bsObjFurn = soup(furniture_raw.content, 'html.parser')
furniture_listings = bsObjFurn.find_all(class_="cl-static-search-result")

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
        
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

data
# Out:
# [{'title': '2008 subaru impreza',
#   'price': '$2,000',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-subaru-impreza/7787924583.html',
#   'brand': 'subaru'},
#  {'title': '2018 tesla model 3 mid range or 2018 tesla model s75d awd',
#   'price': '$16,900',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2018-tesla-model-mid-range-or/7787917504.html',
#   'brand': 'tesla'},
#  {'title': '2010 lexus is250c convertible',
#   'price': '$14,950',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2010-lexus-is250c/7787904942.html',
#   'brand': 'lexus'},
#  {'title': '2010 chevy malibu 4-door',
#   'price': '$800',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-2010-chevy-malibu-door/7787579204.html',
#   'brand': 'chevy'},
#  {'title': 'bmw x5',
#   'price': '$8,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-bmw-x5/7787579073.html',
#   'brand': 'bmw'},
#  {'title': 'bmw z3',
#   'price': '$5,900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/staunton-bmw-z3/7787567192.html',
#   'brand': 'bmw'},
#  {'title': '1998 toyota camery',
#   'price': '$1,500',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1998-toyota-camery/7787566957.html',
#   'brand': 'toyota'},
#  {'title': 'military m35',
#   'price': '$2,700',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/free-union-military-m35/7787336357.html',
#   'brand': 'missing'},
#  {'title': '2010 e550 mercedes sedan',
#   'price': '$7,650',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2010-e550-mercedes-sedan/7787286459.html',
#   'brand': 'missing'},
#  {'title': 'dodge 4x4',
#   'price': '$3,700',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/banco-dodge-4x4/7787130319.html',
#   'brand': 'dodge'},
#  {'title': 'buick',
#   'price': '$4,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-buick/7787002324.html',
#   'brand': 'buick'},
#  {'title': '2000 chevy blazer',
#   'price': '$1,000',
#   'year': '2000',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2000-chevy-blazer/7787001176.html',
#   'brand': 'chevy'},
#  {'title': 'affordable car works well',
#   'price': '$1,950',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-affordable-car-works-well/7786935849.html',
#   'brand': 'missing'},
#  {'title': '1998 chevy pickup',
#   'price': '$2,500',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1998-chevy-pickup/7786804053.html',
#   'brand': 'chevy'},
#  {'title': '2004 chevy blazer',
#   'price': '$4,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2004-chevy-blazer/7786802056.html',
#   'brand': 'chevy'},
#  {'title': '2007 mercedes benz c280 or 2005 benz e500 4matic $3950',
#   'price': '$4,950',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2007-mercedes-benz-c280-or-2005/7786722300.html',
#   'brand': 'missing'},
#  {'title': '2005 nissan maxima se',
#   'price': '$3,500',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/cto/d/dillwyn-2005-nissan-maxima-se/7786586063.html',
#   'brand': 'missing'},
#  {'title': '2012 subaru impreza 2.0i premium sedan 4d',
#   'price': '$7,400',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2012-subaru-impreza-20i/7786582182.html',
#   'brand': 'subaru'},
#  {'title': '2008 chevrolet silverado',
#   'price': '$6,000',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stuarts-draft-2008-chevrolet-silverado/7786493479.html',
#   'brand': 'chevrolet'},
#  {'title': '2012 honda civic lx',
#   'price': '$5,900',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2012-honda-civic-lx/7786413068.html',
#   'brand': 'honda'},
#  {'title': 'f-350 6.0 diesel service body',
#   'price': '$13,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-diesel-service-body/7786360711.html',
#   'brand': 'missing'},
#  {'title': '2007 honda element ex',
#   'price': '$8,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2007-honda-element-ex/7786323697.html',
#   'brand': 'honda'},
#  {'title': '85 short bed chevy',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-85-short-bed-chevy/7786302799.html',
#   'brand': 'chevy'},
#  {'title': '2004 audi a6 2.7t s-line quatro sedan 4d',
#   'price': '$1,200',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2004-audi-a6-27t-line/7786238457.html',
#   'brand': 'audi'},
#  {'title': '2001 ford 250, 7.3 diesel, 4 x  4 ,with storage bin cap',
#   'price': '$10,900',
#   'year': '2001',
#   'link': 'https://charlottesville.craigslist.org/cto/d/pratts-2001-ford-diesel-x-with-storage/7786230476.html',
#   'brand': 'ford'},
#  {'title': '1989 chevrolet silverado 4x4',
#   'price': '$17,500',
#   'year': '1989',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1989-chevrolet/7786188892.html',
#   'brand': 'chevrolet'},
#  {'title': 'affordable car works well',
#   'price': '$1,950',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-affordable-car-works-well/7786056040.html',
#   'brand': 'missing'},
#  {'title': '2010 jaguar xk',
#   'price': '$21,900',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/boston-2010-jaguar-xk/7785824836.html',
#   'brand': 'missing'},
#  {'title': '2015 honda odyssey ex',
#   'price': '$9,950',
#   'year': '2015',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2015-honda-odyssey-ex/7785813701.html',
#   'brand': 'honda'},
#  {'title': '2005 hyundai elantra',
#   'price': '$1,200',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/cto/d/afton-2005-hyundai-elantra/7785683810.html',
#   'brand': 'missing'},
#  {'title': '2007 f250 king ranch',
#   'price': '$17,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-2007-f250-king-ranch/7785680751.html',
#   'brand': 'missing'},
#  {'title': '1998 gmc sierra 1500 sl truck auto rwd <103,000 miles',
#   'price': '$6,250',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-1998-gmc-sierra-1500-sl-truck/7785561584.html',
#   'brand': 'gmc'},
#  {'title': '2006 honda pilot exl fwd',
#   'price': '$4,700',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2006-honda-pilot-exl-fwd/7785499961.html',
#   'brand': 'honda'},
#  {'title': '2015 gmc terrain - good condition',
#   'price': '$3,500',
#   'year': '2015',
#   'link': 'https://charlottesville.craigslist.org/cto/d/keswick-2015-gmc-terrain-good-condition/7785267240.html',
#   'brand': 'gmc'},
#  {'title': 'buick',
#   'price': '$4,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-buick/7785078444.html',
#   'brand': 'buick'},
#  {'title': 'jeep wrangler',
#   'price': '$12,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-jeep-wrangler/7785014681.html',
#   'brand': 'jeep'},
#  {'title': '2007 toyota camry v6 xle',
#   'price': '$4,100',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2007-toyota-camry-v6-xle/7785001447.html',
#   'brand': 'toyota'},
#  {'title': '1994 chevy s10',
#   'price': '$4,000',
#   'year': '1994',
#   'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-1994-chevy-s10/7784965289.html',
#   'brand': 'chevy'},
#  {'title': 'toyota 4runner',
#   'price': '$3,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-toyota-4runner/7784875544.html',
#   'brand': 'toyota'},
#  {'title': '1962 m38-a1 military jeep',
#   'price': '$1,500',
#   'year': '1962',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1962-m38-a1-military-jeep/7784860520.html',
#   'brand': 'jeep'},
#  {'title': '2010 avalanche',
#   'price': '$5,500',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/mineral-2010-avalanche/7784792017.html',
#   'brand': 'missing'},
#  {'title': 'dodge m37 powerwagon',
#   'price': '$7,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/piney-river-dodge-m37-powerwagon/7784758445.html',
#   'brand': 'dodge'},
#  {'title': '2018 toyota tacoma truck sr5 4wd double cab, 6 cyl, auto, 30,000 miles',
#   'price': '$30,550',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-2018-toyota-tacoma-truck-sr5-4wd/7784680777.html',
#   'brand': 'toyota'},
#  {'title': '2003 toyota highlander',
#   'price': '$3,300',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/lovingston-2003-toyota-highlander/7784607564.html',
#   'brand': 'toyota'},
#  {'title': '2011 chrysler town and country',
#   'price': '$2,500',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2011-chrysler-town-and/7784233445.html',
#   'brand': 'missing'},
#  {'title': '2006 mitsubishi endeavor awd ls',
#   'price': '$3,200',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2006-mitsubishi/7784157813.html',
#   'brand': 'mitsubishi'},
#  {'title': '2019 hyundai kona excellent condition',
#   'price': '$15,000',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2019-hyundai-kona/7783977835.html',
#   'brand': 'missing'},
#  {'title': '2011 bmw 328i xdrive sedan 4d',
#   'price': '$6,000',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2011-bmw-328i-xdrive/7783905386.html',
#   'brand': 'bmw'},
#  {'title': '2008 subaru outback',
#   'price': '$5,800',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-subaru-outback/7783889756.html',
#   'brand': 'subaru'},
#  {'title': '2004 dodge durango',
#   'price': '$2,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stanardsville-2004-dodge-durango/7783863430.html',
#   'brand': 'dodge'},
#  {'title': '2012 ford focus se',
#   'price': '$3,500',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2012-ford-focus-se/7783801610.html',
#   'brand': 'ford'},
#  {'title': '2008 ford escape xlt 4x4 3.0',
#   'price': '$1,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-2008-ford-escape-xlt-4x4-30/7783759838.html',
#   'brand': 'ford'},
#  {'title': 'mercedes 560sl',
#   'price': '$15,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-mercedes-560sl/7783648170.html',
#   'brand': 'missing'},
#  {'title': '2013 honda fit sport hatchback',
#   'price': '$8,700',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/afton-2013-honda-fit-sport-hatchback/7783561831.html',
#   'brand': 'honda'},
#  {'title': '1986 ford e350 centurion',
#   'price': '$11,500',
#   'year': '1986',
#   'link': 'https://charlottesville.craigslist.org/cto/d/helena-1986-ford-e350-centurion/7783532418.html',
#   'brand': 'ford'},
#  {'title': '2014 honda odyssey van black',
#   'price': '$12,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2014-honda-odyssey-van-black/7783477164.html',
#   'brand': 'honda'},
#  {'title': 'military truck w/crane',
#   'price': '$6,200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/free-union-military-truck-crane/7783324663.html',
#   'brand': 'missing'},
#  {'title': 'volvo s40 4dr sedan 2004 power everything sun roof',
#   'price': '$2,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-volvo-s40-4dr-sedan/7783322114.html',
#   'brand': 'volvo'},
#  {'title': '2004 honda accord for sale $5,000 or best offer',
#   'price': '$5,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-honda-accord-for/7783266346.html',
#   'brand': 'honda'},
#  {'title': '2003 honda pilot',
#   'price': '$1,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2003-honda-pilot/7783239203.html',
#   'brand': 'honda'},
#  {'title': '2002 chevy tahoe 4wd',
#   'price': '$4,000',
#   'year': '2002',
#   'link': 'https://charlottesville.craigslist.org/cto/d/montpelier-station-2002-chevy-tahoe-4wd/7783219894.html',
#   'brand': 'chevy'},
#  {'title': '2008 nissan altima (read description)',
#   'price': '$1,350',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/ruckersville-2008-nissan-altima-read-de/7783180089.html',
#   'brand': 'missing'},
#  {'title': '2016 tesla model s 90d',
#   'price': '$26,000',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2016-tesla-model-90d/7783168254.html',
#   'brand': 'tesla'},
#  {'title': '2010 volkswagen golf',
#   'price': '$4,950',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2010-volkswagen-golf/7783125171.html',
#   'brand': 'volkswagen'},
#  {'title': '1963 /1965 triumph tr4 convertible',
#   'price': '$2,250',
#   'year': '1963',
#   'link': 'https://charlottesville.craigslist.org/cto/d/woodberry-forest-triumph-tr4-convertible/7782965513.html',
#   'brand': 'missing'},
#  {'title': '1998 jeep grande cherokee laredo',
#   'price': '$3,000',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-1998-jeep-grande-cherokee/7782899240.html',
#   'brand': 'jeep'},
#  {'title': '1996 chevrolet k1500 z71',
#   'price': '$6,500',
#   'year': '1996',
#   'link': 'https://charlottesville.craigslist.org/cto/d/keswick-1996-chevrolet-k1500-z71/7782892110.html',
#   'brand': 'chevrolet'},
#  {'title': '1971 sport convertible',
#   'price': '$25,000',
#   'year': '1971',
#   'link': 'https://charlottesville.craigslist.org/cto/d/culpeper-1971-sport-convertible/7782818548.html',
#   'brand': 'missing'},
#  {'title': 'dodge dakota 4wd',
#   'price': '$10,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-dodge-dakota-4wd/7782614108.html',
#   'brand': 'dodge'},
#  {'title': '2014 bmw x3 with blown engine',
#   'price': '$3,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-bmw-x3-with-blown/7782218430.html',
#   'brand': 'bmw'},
#  {'title': 'ford f150 5.4 triton',
#   'price': '$7,250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/fishersville-ford-triton/7782209120.html',
#   'brand': 'ford'},
#  {'title': '2007 ford xlt fx, 4-dr., supercab, sidestyle, 5.4-liter v8',
#   'price': '$8,300',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2007-ford-xlt-fx-dr-supercab/7782091017.html',
#   'brand': 'ford'},
#  {'title': '1999 mx-5 miata covertible coupe',
#   'price': '$6,500',
#   'year': '1999',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1999-mx-miata/7781918639.html',
#   'brand': 'missing'},
#  {'title': 'dodge 4x4 slt',
#   'price': '$6,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-dodge-4x4-slt/7781868229.html',
#   'brand': 'dodge'},
#  {'title': '1992 honda accord gas sipper',
#   'price': '$2,899',
#   'year': '1992',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1992-honda-accord-gas/7781862579.html',
#   'brand': 'honda'},
#  {'title': '2003 jeep wrangler',
#   'price': '$19,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2003-jeep-wrangler/7781774156.html',
#   'brand': 'jeep'},
#  {'title': 'yes i have title',
#   'price': '$2,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-yes-have-title/7781670977.html',
#   'brand': 'missing'},
#  {'title': '2016 kia sorento',
#   'price': '$9,500',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/haywood-2016-kia-sorento/7781590995.html',
#   'brand': 'kia'},
#  {'title': '2008 acura tl',
#   'price': '$3,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-acura-tl/7781590435.html',
#   'brand': 'acura'},
#  {'title': '*for sale* subaru outback 2007',
#   'price': '$3,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/gordonsville-for-sale-subaru-outback/7781590306.html',
#   'brand': 'subaru'},
#  {'title': 'audi allroad',
#   'price': '$11,665',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-audi-allroad/7781459189.html',
#   'brand': 'audi'},
#  {'title': '2004 f150',
#   'price': '$3,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-f150/7781429289.html',
#   'brand': 'missing'},
#  {'title': '2011 mercury gran marquis ls',
#   'price': '$3,600',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stanardsville-2011-mercury-gran-marquis/7781391243.html',
#   'brand': 'missing'},
#  {'title': 'beautiful 2019 mercedes 300c convertible',
#   'price': '$31,950',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-beautiful-2019-mercedes/7781346288.html',
#   'brand': 'missing'},
#  {'title': 'toyota corolla 2018',
#   'price': '$11,000',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-toyota-corolla-2018/7781210696.html',
#   'brand': 'toyota'},
#  {'title': '2009 kia rondo ex 145k miles',
#   'price': '$3,500',
#   'year': '2009',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-2009-kia-rondo-ex-145k-miles/7780623128.html',
#   'brand': 'kia'},
#  {'title': '2002 gmc 3500 4x4 extended cab utility bed',
#   'price': '$8,900',
#   'year': '2002',
#   'link': 'https://charlottesville.craigslist.org/cto/d/piney-river-2002-gmc-x4-extended-cab/7780543822.html',
#   'brand': 'gmc'},
#  {'title': 'volvo 240 sedan 1992',
#   'price': '$2,100',
#   'year': '1992',
#   'link': 'https://charlottesville.craigslist.org/cto/d/esmont-volvo-240-sedan-1992/7780475292.html',
#   'brand': 'volvo'},
#  {'title': '2006 hyundai azera limited',
#   'price': '$3,250',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-2006-hyundai-azera-limited/7780464989.html',
#   'brand': 'missing'},
#  {'title': '2018 subaru forester 2.5i touring cvt',
#   'price': '$22,000',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/roseland-2018-subaru-forester-25i/7780319702.html',
#   'brand': 'subaru'},
#  {'title': 'car for sale',
#   'price': '$10,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-car-for-sale/7780257892.html',
#   'brand': 'missing'},
#  {'title': '1969 chevelle for sale or trade',
#   'price': '$28,500',
#   'year': '1969',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-1969-chevelle-for-sale-or/7780220803.html',
#   'brand': 'missing'},
#  {'title': '1989 chevrolet corvette convertible',
#   'price': '$5,000',
#   'year': '1989',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1989-chevrolet-corvette/7779874166.html',
#   'brand': 'chevrolet'},
#  {'title': '2008 toyota prius',
#   'price': '$7,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-toyota-prius/7779766112.html',
#   'brand': 'toyota'},
#  {'title': '2021 toyota rav 4 prime hybrid',
#   'price': '$38,000',
#   'year': '2021',
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-2021-toyota-rav-prime-hybrid/7779746384.html',
#   'brand': 'toyota'},
#  {'title': '2007 2500 gmc sierra hd classic',
#   'price': '$4,200',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-gmc-sierra-hd-classic/7779516916.html',
#   'brand': 'gmc'},
#  {'title': '2019 ram promaster 1500',
#   'price': '$18,500',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2019-ram-promaster-1500/7779509064.html',
#   'brand': 'missing'},
#  {'title': '1958 ford fairlane 500',
#   'price': '$18,500',
#   'year': '1958',
#   'link': 'https://charlottesville.craigslist.org/cto/d/leon-1958-ford-fairlane-500/7779305738.html',
#   'brand': 'ford'},
#  {'title': '2014 honda crv ex-l cr-v',
#   'price': '$13,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-honda-crv-ex-cr/7779300072.html',
#   'brand': 'honda'},
#  {'title': '2005 ford f-150 2wd- not running',
#   'price': '$1,000',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2005-ford-150-2wd-not/7779296183.html',
#   'brand': 'ford'},
#  {'title': '2001 mercedes e320',
#   'price': '$3,000',
#   'year': '2001',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2001-mercedes-e320/7779120462.html',
#   'brand': 'missing'},
#  {'title': '2007 subaru outback',
#   'price': '$2,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/oakpark-2007-subaru-outback/7778984172.html',
#   'brand': 'subaru'}]

# %%
import string
furniture_types = ['table', 'chair', 'chairs', 'shelving','rug', 'mattress', 'hutch', 'bed', 'dresser', 'cabinet', 'nightstand', 'nightstands', 'desk', 'desks']
furniture_data = []
for k in range( len(furniture_listings) ):
    title = furniture_listings[k].find('div',class_='title').get_text().lower()
    title_without_punctuation = title.translate(str.maketrans('', '', string.punctuation))
    price = furniture_listings[k].find('div',class_='price').get_text()
    link = furniture_listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title_without_punctuation.split()
    furn_hits = [word for word in words if word in furniture_types] # Find brands in the title
    
    if len(furn_hits) == 0:
        furniture_type = 'missing'
    else:
        furniture_type = furn_hits[0]

    furniture_data.append({'title':title,'price':price,'link':link,'type':furniture_type})
furniture_data
# Out:
# [{'title': 'west elm lena mid-century dining chairs',
#   'price': '$450',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-west-elm-lena-mid-century/7787967454.html',
#   'type': 'chairs'},
#  {'title': 'leather/wood foldable chair!',
#   'price': '$95',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-leather-wood-foldable-chair/7784346232.html',
#   'type': 'chair'},
#  {'title': 'solid wood accent table!',
#   'price': '$95',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-solid-wood-accent-table/7784345824.html',
#   'type': 'table'},
#  {'title': 'queen mattress & box spring! brand new!',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-queen-mattress-box-spring/7785093904.html',
#   'type': 'mattress'},
#  {'title': 'china hutch',
#   'price': '$49',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-china-hutch/7785484049.html',
#   'type': 'hutch'},
#  {'title': 'queen platform bed frame and headboard',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-queen-platform-bed-frame-and/7787932213.html',
#   'type': 'bed'},
#  {'title': 'iron foldable shelving rack!',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-iron-foldable-shelving-rack/7787282965.html',
#   'type': 'shelving'},
#  {'title': 'wood table and 6 chairs.',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-wood-table-and-chairs/7787924485.html',
#   'type': 'table'},
#  {'title': 'mid century chrome and glass table set',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-mid-century-chrome-and/7784068562.html',
#   'type': 'table'},
#  {'title': 'tempered glass and steel occasional tables',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-tempered-glass-and/7782500616.html',
#   'type': 'missing'},
#  {'title': 'deluxe double storage ottoman',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-deluxe-double-storage/7782502222.html',
#   'type': 'missing'},
#  {'title': 'oak file cabinets and desk top group',
#   'price': '$325',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-oak-file-cabinets-and/7782448796.html',
#   'type': 'desk'},
#  {'title': 'pristine! mid century modern credenza - american of martinsville dania',
#   'price': '$1,400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/yorktown-pristine-mid-century-modern/7784339958.html',
#   'type': 'missing'},
#  {'title': 'desk chairs',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-desk-chairs/7787767264.html',
#   'type': 'desk'},
#  {'title': '6 boxes of glasses/cups/dishes',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-boxes-of-glasses-cups-dishes/7786392577.html',
#   'type': 'missing'},
#  {'title': 'kincaid tuscano solid wood marble top bedside chest',
#   'price': '$500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-kincaid-tuscano-solid-wood/7782576483.html',
#   'type': 'missing'},
#  {'title': 'vintage  hand made solid wooden coffee and side table',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-hand-made-solid/7782119962.html',
#   'type': 'table'},
#  {'title': 'serta twin box spring & mattress',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-serta-twin-box-spring/7787742512.html',
#   'type': 'mattress'},
#  {'title': 'turntable console with cd player and am/fm tuner',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-turntable-console-with-cd/7782578434.html',
#   'type': 'missing'},
#  {'title': '" little golden books " revolving book rack',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/dyke-little-golden-books-revolving-book/7782795290.html',
#   'type': 'missing'},
#  {'title': 'antique / vintage wooden ironing board',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/dyke-antique-vintage-wooden-ironing/7782801648.html',
#   'type': 'missing'},
#  {'title': 'oak vintage wrought iron ice cream parlor set',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/dyke-oak-vintage-wrought-iron-ice-cream/7782810789.html',
#   'type': 'missing'},
#  {'title': 'mirror with wooden frame',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/dyke-mirror-with-wooden-frame/7782958400.html',
#   'type': 'missing'},
#  {'title': 'vintage solid wooden handmade dining table',
#   'price': '$450',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-solid-wooden/7787663822.html',
#   'type': 'table'},
#  {'title': '29" high / bar chairs for sale or both for',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-29-high-bar-chairs/7782026590.html',
#   'type': 'chairs'},
#  {'title': 'great condition chair $40 or best offer',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-great-condition-chair/7786837969.html',
#   'type': 'chair'},
#  {'title': 'great condition kitchen cabinet for sale $200 or best offer',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-great-condition-kitchen/7786842741.html',
#   'type': 'cabinet'},
#  {'title': 'mid century magnolia gold painted lamps',
#   'price': '$80',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-mid-century-magnolia-gold/7782872619.html',
#   'type': 'missing'},
#  {'title': 'recliner',
#   'price': '$600',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-recliner/7787596145.html',
#   'type': 'missing'},
#  {'title': 'canon all-in-one printer wireless',
#   'price': '$120',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-canon-all-in-one-printer/7780323617.html',
#   'type': 'missing'},
#  {'title': 'camping folding chair',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/culpeper-camping-folding-chair/7785673179.html',
#   'type': 'chair'},
#  {'title': 'beautiful artificial indoor tree',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-artificial/7786400103.html',
#   'type': 'missing'},
#  {'title': 'pair of vintage berman bronze & art glass deco style table lamps',
#   'price': '$125',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-vintage-berman/7780279957.html',
#   'type': 'table'},
#  {'title': 'americanflat 11" x 14" new picture frame 2 pack',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-americanflat-11-14-new/7782857811.html',
#   'type': 'missing'},
#  {'title': 'colonial maple rocker',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-colonial-maple-rocker/7779297288.html',
#   'type': 'missing'},
#  {'title': 'green polka dot chair cushions',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-green-polka-dot-chair/7779296890.html',
#   'type': 'chair'},
#  {'title': '2 wood dine chairs/cushions',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-dine-chairs-cushions/7787533014.html',
#   'type': 'missing'},
#  {'title': 'framed picture',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-framed-picture/7787532873.html',
#   'type': 'missing'},
#  {'title': 'small table dainty decorative legs',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-table-dainty-decorative-legs/7787489766.html',
#   'type': 'table'},
#  {'title': '"parallel bed" - design within reach - king size',
#   'price': '$900',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keswick-parallel-bed-design-within/7787485271.html',
#   'type': 'bed'},
#  {'title': 'vintage brass hurricane lamp white swirl glass shade',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-brass-hurricane-lamp-white/7787465741.html',
#   'type': 'missing'},
#  {'title': 'cherry dining table',
#   'price': '$600',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/buena-vista-cherry-dining-table/7780938609.html',
#   'type': 'table'},
#  {'title': 'unopened 72 bottle wine rack',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/ruckersville-unopened-72-bottle-wine/7785053770.html',
#   'type': 'missing'},
#  {'title': 'wall art',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wall-art/7787437476.html',
#   'type': 'missing'},
#  {'title': 'stain glass hanging fixture',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-stain-glass-hanging-fixture/7787432972.html',
#   'type': 'missing'},
#  {'title': 'drop leaf table 4 chairs',
#   'price': '$125',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-drop-leaf-table-chairs/7787430738.html',
#   'type': 'table'},
#  {'title': 'twin over full futon bunk bed',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-twin-over-full-futon/7787392934.html',
#   'type': 'bed'},
#  {'title': 'vintage wood desk',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-wood-desk/7787387031.html',
#   'type': 'desk'},
#  {'title': 'desks',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-desks/7786770517.html',
#   'type': 'desks'},
#  {'title': 'nightstands',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-nightstands/7786773886.html',
#   'type': 'nightstands'},
#  {'title': 'set of 2 corliving woodgrove white wash wood barstool with leatherette',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-set-of-corliving-woodgrove/7784057996.html',
#   'type': 'missing'},
#  {'title': 'hooker furniture living room brookhaven end table',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-hooker-furniture-living/7784058056.html',
#   'type': 'table'},
#  {'title': 'vintage floor glass table lamp',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-floor-glass-table-lamp/7787336977.html',
#   'type': 'table'},
#  {'title': 'wooden rocking chair & glider',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wooden-rocking-chair-glider/7786243181.html',
#   'type': 'chair'},
#  {'title': 'decorative table lamp',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-decorative-table-lamp/7787245524.html',
#   'type': 'table'},
#  {'title': 'porch bed with outdoor cushions',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/hood-porch-bed-with-outdoor-cushions/7787245392.html',
#   'type': 'bed'},
#  {'title': 'tall decorative lamp floor/table',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-tall-decorative-lamp-floor-table/7787244399.html',
#   'type': 'missing'},
#  {'title': 'desk storage space behind door',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-desk-storage-space-behind-door/7787242205.html',
#   'type': 'desk'},
#  {'title': 'decorative chair',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-decorative-chair/7787242060.html',
#   'type': 'chair'},
#  {'title': 'wide seat bar chair',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wide-seat-bar-chair/7778951679.html',
#   'type': 'chair'},
#  {'title': 'kidkraft desk/hutch',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-kidkraft-desk-hutch/7778951814.html',
#   'type': 'missing'},
#  {'title': '2 seat loveseat recliners',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-seat-loveseat-recliners/7778951857.html',
#   'type': 'missing'},
#  {'title': 'entertainment center/glass door/drawers',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-entertainment-center-glass-door/7778951892.html',
#   'type': 'missing'},
#  {'title': 'swivel heavy fabric seat bar stools',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-swivel-heavy-fabric-seat-bar-stools/7778951935.html',
#   'type': 'missing'},
#  {'title': 'heavy wood framed mirror',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-heavy-wood-framed-mirror/7779057000.html',
#   'type': 'missing'},
#  {'title': 'table (3) chairs',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-table-chairs/7779232961.html',
#   'type': 'table'},
#  {'title': 'file cabinet',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-file-cabinet/7779507392.html',
#   'type': 'cabinet'},
#  {'title': 'table/2 chairs',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-table-chairs/7779767514.html',
#   'type': 'chairs'},
#  {'title': 'heavy framed picture',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-heavy-framed-picture/7780277755.html',
#   'type': 'missing'},
#  {'title': 'small tv/2 tier table rollers',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-tv-tier-table-rollers/7780418908.html',
#   'type': 'table'},
#  {'title': 'vintage rocking chair',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-rocking-chair/7780607484.html',
#   'type': 'chair'},
#  {'title': 'metal leg work table',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-leg-work-table/7781532593.html',
#   'type': 'table'},
#  {'title': 'new mirrored wall art sound/lights package',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-new-mirrored-wall-art-sound-lights/7781722617.html',
#   'type': 'missing'},
#  {'title': 'glider rocking wood chair',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-glider-rocking-wood-chair/7781722775.html',
#   'type': 'chair'},
#  {'title': 'antique washstand/mirror',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-antique-washstand-mirror/7781723224.html',
#   'type': 'missing'},
#  {'title': 'old (3) heavy chairs',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-old-heavy-chairs/7782290568.html',
#   'type': 'chairs'},
#  {'title': 'lamp table shelf bottom',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-lamp-table-shelf-bottom/7782301376.html',
#   'type': 'table'},
#  {'title': 'twin bed/frame/headboards/mattress/slats frame',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-twin-bed-frame-headboards-mattress/7782301586.html',
#   'type': 'missing'},
#  {'title': 'wood frame train station picture',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-frame-train-station-picture/7782327922.html',
#   'type': 'missing'},
#  {'title': 'vintage wood school desk',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-wood-school-desk/7782336547.html',
#   'type': 'desk'},
#  {'title': 'cherry 2 drawer file cabinet',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-cherry-drawer-file-cabinet/7782337195.html',
#   'type': 'cabinet'},
#  {'title': '2 chairs have white cover',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-chairs-have-white-cover/7782354345.html',
#   'type': 'chairs'},
#  {'title': 'vintage heavy wrought iron patio set',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-heavy-wrought-iron-patio/7783118014.html',
#   'type': 'missing'},
#  {'title': 'night stand',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-night-stand/7783118797.html',
#   'type': 'missing'},
#  {'title': 'large metal table goes over barbecue',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-large-metal-table-goes-over/7783124218.html',
#   'type': 'table'},
#  {'title': 'older file cabinet',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-older-file-cabinet/7783132204.html',
#   'type': 'cabinet'},
#  {'title': 'swivel bar stool',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-swivel-bar-stool/7783132311.html',
#   'type': 'missing'},
#  {'title': 'wood dining chair',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-dining-chair/7783132391.html',
#   'type': 'chair'},
#  {'title': 'small black office chair',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-black-office-chair/7783132496.html',
#   'type': 'chair'},
#  {'title': 'solid cherry headboard, footboard, frame',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-solid-cherry-headboard-footboard/7783133884.html',
#   'type': 'missing'},
#  {'title': 'vintage desk',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-desk/7783312164.html',
#   'type': 'desk'},
#  {'title': 'cabinet (4) drawers',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-cabinet-drawers/7784367273.html',
#   'type': 'cabinet'},
#  {'title': '2 tier stand',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-tier-stand/7784370885.html',
#   'type': 'missing'},
#  {'title': 'bookcase/display shelves',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-bookcase-display-shelves/7784370996.html',
#   'type': 'missing'},
#  {'title': 'andres orpinas sign blue monochromics print',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-andres-orpinas-sign-blue/7784371093.html',
#   'type': 'missing'},
#  {'title': 'white stand (9) display storage spaces',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-white-stand-display-storage-spaces/7784385090.html',
#   'type': 'missing'},
#  {'title': 'from japan (2) hand painted lamps',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-from-japan-hand-painted-lamps/7785198881.html',
#   'type': 'missing'},
#  {'title': 'framed mirror 27"x 31"',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-framed-mirror-27x-31/7785235104.html',
#   'type': 'missing'},
#  {'title': '3 seat couch recliner each end',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-seat-couch-recliner-each-end/7785369769.html',
#   'type': 'missing'},
#  {'title': 'vintage victorian tuff parlor chair',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-victorian-tuff-parlor-chair/7786374354.html',
#   'type': 'chair'},
#  {'title': 'global safari art prints signed by tina chaden',
#   'price': '$125',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-global-safari-art/7778435799.html',
#   'type': 'missing'},
#  {'title': 'beautiful solid oak computer desk',
#   'price': '$225',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-solid-oak/7778440693.html',
#   'type': 'desk'},
#  {'title': '(2)  heavy lateral (2) drawer file cabinets',
#   'price': '$80',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-heavy-lateral-drawer-file-cabinets/7786515050.html',
#   'type': 'missing'},
#  {'title': 'large 3 tier cart',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-large-tier-cart/7786515253.html',
#   'type': 'missing'},
#  {'title': '2 metal frame design top/fabric seats chairs',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-frame-design-top-fabric/7786568796.html',
#   'type': 'chairs'},
#  {'title': 'small wood replica school desk',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-wood-replica-school-desk/7786651840.html',
#   'type': 'desk'},
#  {'title': 'decorative wood magazine rack',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-decorative-wood-magazine-rack/7786666380.html',
#   'type': 'missing'},
#  {'title': 'light blue klaussner loveseat',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-light-blue-klaussner-loveseat/7783088073.html',
#   'type': 'missing'},
#  {'title': 'two ikea cabinets with glass',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-two-ikea-cabinets-with-glass/7787184117.html',
#   'type': 'missing'},
#  {'title': 'brown dresser ikea style',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-brown-dresser-ikea-style/7787182971.html',
#   'type': 'dresser'},
#  {'title': 'hand crafted stand up pine cabinet',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-hand-crafted-stand-up-pine-cabinet/7787182479.html',
#   'type': 'cabinet'},
#  {'title': 'wood and metal ikea desk chair',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-wood-and-metal-ikea/7787122036.html',
#   'type': 'desk'},
#  {'title': 'indoor/outdoor orange chair',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-indoor-outdoor-orange/7787080872.html',
#   'type': 'chair'},
#  {'title': 'antique buffet cabinet server',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-antique-buffet-cabinet-server/7786307383.html',
#   'type': 'cabinet'},
#  {'title': 'three vintage enamel top tables- $75 each',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-three-vintage-enamel/7787005172.html',
#   'type': 'missing'},
#  {'title': 'sailboats on the sea triptych " by third and wall 3 - pieces',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-sailboats-on-the-sea-triptych/7787002142.html',
#   'type': 'missing'},
#  {'title': '8 x 11 hand-knotted noah jute rug anthropologie',
#   'price': '$225',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-x-11-hand-knotted-noah/7784243151.html',
#   'type': 'rug'},
#  {'title': 'anthropologie ashley pendant light',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-anthropologie-ashley/7781975768.html',
#   'type': 'missing'},
#  {'title': '4 wood/fabric seat dining chairs',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-fabric-seat-dining-chairs/7786997707.html',
#   'type': 'chairs'},
#  {'title': 'large tree collage art print',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-large-tree-collage-art/7778530838.html',
#   'type': 'missing'},
#  {'title': 'abstract matted and framed art prints',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-abstract-matted-and/7778532206.html',
#   'type': 'missing'},
#  {'title': 'mackenzie dow dining table with chairs',
#   'price': '$4,800',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/afton-mackenzie-dow-dining-table-with/7786916733.html',
#   'type': 'table'},
#  {'title': '9\'x12" stickley chobi blassic floral ushak rug',
#   'price': '$1,500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/afton-9x12-stickley-chobi-blassic/7786916677.html',
#   'type': 'rug'},
#  {'title': 'mackenzie dow brighton buffet',
#   'price': '$2,250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/afton-mackenzie-dow-brighton-buffet/7786915747.html',
#   'type': 'missing'},
#  {'title': 'costco black mesh office chair',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-costco-black-mesh/7786895026.html',
#   'type': 'chair'},
#  {'title': 'vladimir kagan style mid century cream embossed curved couch sofa',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/woodberry-forest-vladimir-kagan-style/7786859521.html',
#   'type': 'missing'},
#  {'title': 'corduroy couch',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/nellysford-corduroy-couch/7786788486.html',
#   'type': 'missing'},
#  {'title': 'beverage cart, cast iron, with everything on it',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-beverage-cart-cast-iron-with/7784348962.html',
#   'type': 'missing'},
#  {'title': 'ikea queen bed - black wood',
#   'price': '$120',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ikea-queen-bed-black/7786744205.html',
#   'type': 'bed'},
#  {'title': 'club chairs',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-club-chairs/7786725595.html',
#   'type': 'chairs'},
#  {'title': 'club chairs',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-club-chairs/7786724247.html',
#   'type': 'chairs'},
#  {'title': 'metal bondage bench',
#   'price': '$125',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-metal-bondage-bench/7786709434.html',
#   'type': 'missing'},
#  {'title': 'medicine/battroom cabinet',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-medicine-battroom/7786708918.html',
#   'type': 'cabinet'},
#  {'title': 'glass coffee table',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-glass-coffee-table/7786707211.html',
#   'type': 'table'},
#  {'title': 'vintage marble top side table with drawer',
#   'price': '$90',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-marble-top-side/7778804883.html',
#   'type': 'table'},
#  {'title': 'hamadan persian oriental rug runner',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-hamadan-persian-oriental-rug/7786634592.html',
#   'type': 'rug'},
#  {'title': 'afshar persian oriental rug',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-afshar-persian-oriental-rug/7786632623.html',
#   'type': 'rug'},
#  {'title': 'ikea trotten underframe sit/stand desk',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ikea-trotten-underframe/7786615991.html',
#   'type': 'desk'},
#  {'title': 'grapevine table',
#   'price': '$2,800',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/somerset-grapevine-table/7777828876.html',
#   'type': 'table'},
#  {'title': 'large picture frame',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/afton-large-picture-frame/7786447239.html',
#   'type': 'missing'},
#  {'title': 'wood twin headboard',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/wood-twin-headboard/7786447082.html',
#   'type': 'missing'},
#  {'title': 'lamp ruffle shade glass',
#   'price': '$8',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-lamp-ruffle-shade-glass/7778130547.html',
#   'type': 'missing'},
#  {'title': 'small  wood rocking chair',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-wood-rocking-chair/7786381650.html',
#   'type': 'chair'},
#  {'title': 'vintage cedar chest',
#   'price': '$90',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-cedar-chest/7786381625.html',
#   'type': 'missing'},
#  {'title': 'desk/chair',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-desk-chair/7778118170.html',
#   'type': 'missing'},
#  {'title': 'desk lamp goose neck/base holder',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-desk-lamp-goose-neck-base-holder/7784364555.html',
#   'type': 'desk'},
#  {'title': 'antique cart coffee table',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-antique-cart-coffee/7777614186.html',
#   'type': 'table'},
#  {'title': 'patio table & 4 chairs',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-patio-table-chairs/7786266534.html',
#   'type': 'table'},
#  {'title': 'dining table - solid wood',
#   'price': '$275',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-table-solid-wood/7786264370.html',
#   'type': 'table'},
#  {'title': 'la z boy pinnacle recliner',
#   'price': '$325',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-la-boy-pinnacle-recliner/7786257195.html',
#   'type': 'missing'},
#  {'title': 'solid maple sideboard',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-maple-sideboard/7786234807.html',
#   'type': 'missing'},
#  {'title': 'handmade card/craft/game/study table',
#   'price': '$45',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/pratts-handmade-card-craft-game-study/7786223240.html',
#   'type': 'table'},
#  {'title': 'handmade craft/card/game table.',
#   'price': '$45',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/pratts-handmade-craft-card-game-table/7786215738.html',
#   'type': 'table'},
#  {'title': 'used- large sectional sofa',
#   'price': '$375',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-used-large-sectional-sofa/7786197556.html',
#   'type': 'missing'},
#  {'title': 'dresser with rose design',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dresser-with-rose-design/7779419818.html',
#   'type': 'dresser'},
#  {'title': 'queen mattress',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-queen-mattress/7778894564.html',
#   'type': 'mattress'},
#  {'title': 'brand new king box spring',
#   'price': '$0',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-brand-new-king-box/7786045811.html',
#   'type': 'missing'},
#  {'title': 'couch for sale in charlottesville',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-couch-for-sale-in/7786010152.html',
#   'type': 'missing'},
#  {'title': 'swivel glider recliner in leather',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-swivel-glider-recliner-in/7785985538.html',
#   'type': 'missing'},
#  {'title': 'rivah couch and chair',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-rivah-couch-and-chair/7782105935.html',
#   'type': 'chair'},
#  {'title': 'havertys beige couch',
#   'price': '$120',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/pratts-havertys-beige-couch/7780568413.html',
#   'type': 'missing'},
#  {'title': 'in a new york state of mind table',
#   'price': '$99',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-in-new-york-state-of/7778037848.html',
#   'type': 'table'},
#  {'title': 'beautiful thomasville bedroom suite from the impressions collection',
#   'price': '$2,200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-thomasville/7784527788.html',
#   'type': 'missing'},
#  {'title': 'kids bedroom set - 4 piece twin bedroom set with bonus',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-kids-bedroom-set-piece-twin/7785939918.html',
#   'type': 'missing'},
#  {'title': '3 solid wood display cases',
#   'price': '$129',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-solid-wood-display-cases/7785875444.html',
#   'type': 'missing'},
#  {'title': 'classic 8 bulb chandelier',
#   'price': '$79',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-classic-bulb-chandelier/7785872573.html',
#   'type': 'missing'},
#  {'title': 'vintage farm table 54" x 36" and 4 chairs',
#   'price': '$110',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-vintage-farm-table-54-36-and/7785867098.html',
#   'type': 'table'},
#  {'title': 'end tables',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-end-tables/7784971245.html',
#   'type': 'missing'},
#  {'title': 'photo display room divider',
#   'price': '$38',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-photo-display-room-divider/7785854421.html',
#   'type': 'missing'},
#  {'title': 'black velvet bean bag chair',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-black-velvet-bean-bag/7785810955.html',
#   'type': 'chair'},
#  {'title': 'dining tables to fit your space',
#   'price': '$1,800',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-tables-to-fit/7777148334.html',
#   'type': 'missing'},
#  {'title': 'custom wardrobes and bedroom furniture',
#   'price': '$3,600',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/orange-custom-wardrobes-and-bedroom/7777148364.html',
#   'type': 'missing'},
#  {'title': 'kincaid dining room',
#   'price': '$895',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-kincaid-dining-room/7785788088.html',
#   'type': 'missing'},
#  {'title': 'furniture',
#   'price': '$0',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/nellysford-furniture/7785740891.html',
#   'type': 'missing'},
#  {'title': 'jasper secretary desk',
#   'price': '$750',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/fishersville-jasper-secretary-desk/7785623445.html',
#   'type': 'desk'},
#  {'title': 'child size desk antique',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-child-size-desk-antique/7785580254.html',
#   'type': 'desk'},
#  {'title': '8 by 10 brand new carpet!',
#   'price': '$175',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-by-10-brand-new-carpet/7785316815.html',
#   'type': 'missing'},
#  {'title': 'sturdy, no frills, armless desk chair',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-sturdy-no-frills/7785207076.html',
#   'type': 'desk'},
#  {'title': 'pull-out sleeper sofa: small and comfy',
#   'price': '$325',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pull-out-sleeper-sofa/7778515579.html',
#   'type': 'missing'},
#  {'title': 'like new twin mattress',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-like-new-twin-mattress/7785145814.html',
#   'type': 'mattress'},
#  {'title': 'like new mattress foundation',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-like-new-mattress/7785145325.html',
#   'type': 'mattress'},
#  {'title': 'queen sized nectar mattress',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-queen-sized-nectar/7783978088.html',
#   'type': 'mattress'},
#  {'title': 'hickory chair cardiff sofa',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-hickory-chair-cardiff/7785094835.html',
#   'type': 'chair'},
#  {'title': 'book case - wood',
#   'price': '$40',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-book-case-wood/7785076378.html',
#   'type': 'missing'},
#  {'title': 'extendable wooded dining table - 9ft 6in',
#   'price': '$500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-extendable-wooded/7785034427.html',
#   'type': 'table'},
#  {'title': 'old bicycle from 70s',
#   'price': '$45',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-old-bicycle-from-70s/7784965307.html',
#   'type': 'missing'},
#  {'title': 'armoire',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-armoire/7784960566.html',
#   'type': 'missing'},
#  {'title': 'antique carved dining chairs',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-antique-carved-dining/7784845732.html',
#   'type': 'chairs'},
#  {'title': 'solian ware by soho pottery ltd.',
#   'price': '$89',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-solian-ware-by-soho-pottery-ltd/7784823468.html',
#   'type': 'missing'},
#  {'title': 'pitcher and bowl set by ironstone u.s.a',
#   'price': '$35',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-pitcher-and-bowl-set-by/7784823248.html',
#   'type': 'missing'},
#  {'title': 'rare classic high back solid oak swivel bar stool',
#   'price': '$79',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-rare-classic-high-back-solid/7784820225.html',
#   'type': 'missing'},
#  {'title': 'beautiful high back solid oak swivel bar stool',
#   'price': '$69',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-beautiful-high-back-solid-oak/7784819796.html',
#   'type': 'missing'},
#  {'title': 'white formica portable desk and filing cabinet',
#   'price': '$49',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-white-formica-portable-desk-and/7784817534.html',
#   'type': 'desk'},
#  {'title': 'beautiful vintage lamp with a whiskey barrel base',
#   'price': '$52',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-beautiful-vintage-lamp-with/7784815694.html',
#   'type': 'missing'},
#  {'title': 'black laminate book case',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-black-laminate-book-case/7784814617.html',
#   'type': 'missing'},
#  {'title': 'solid oak wine rack',
#   'price': '$28',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-solid-oak-wine-rack/7784811546.html',
#   'type': 'missing'},
#  {'title': 'mirrors mirrors mirrors from',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-mirrors-mirrors-mirrors-from/7784808149.html',
#   'type': 'missing'},
#  {'title': 'lamps lamps lamps shades shades shades from',
#   'price': '$8',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-lamps-lamps-lamps-shades-shades/7784807556.html',
#   'type': 'missing'},
#  {'title': 'antique white farm table with two leaves 42" x 42" x 28" h + 2@9"',
#   'price': '$99',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-white-farm-table-with/7784805158.html',
#   'type': 'table'},
#  {'title': 'crackle painted side table 21" x 23"',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-crackle-painted-side-table-21-23/7784804272.html',
#   'type': 'table'},
#  {'title': 'cherry burl (for turning)',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/piney-river-cherry-burl-for-turning/7784756079.html',
#   'type': 'missing'},
#  {'title': '4 dining chairs',
#   'price': '$45',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-chairs/7784754257.html',
#   'type': 'chairs'},
#  {'title': 'twin day bed w/mattress',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-twin-day-bed-mattress/7784630492.html',
#   'type': 'bed'},
#  {'title': 'office chair for sale',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-office-chair-for-sale/7784615342.html',
#   'type': 'chair'},
#  {'title': 'professionally framed artwork group',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-professionally-framed/7775563253.html',
#   'type': 'missing'},
#  {'title': 'original h. gailey seascape oil on canvas',
#   'price': '$175',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-original-gailey/7775870955.html',
#   'type': 'missing'},
#  {'title': 'china cabinet',
#   'price': '$700',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keswick-china-cabinet/7784547878.html',
#   'type': 'cabinet'},
#  {'title': 'two articulated desk lamps',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-two-articulated-desk-lamps/7775762337.html',
#   'type': 'desk'},
#  {'title': '3 panel room divider with mirror',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-panel-room-divider-with/7784453021.html',
#   'type': 'missing'},
#  {'title': '8x10 farmhouse rug',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-8x10-farmhouse-rug/7784390578.html',
#   'type': 'rug'},
#  {'title': 'full wood bed',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-full-wood-bed/7784377361.html',
#   'type': 'bed'},
#  {'title': 'dining room table expandable',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-dining-room-table-expandable/7784364079.html',
#   'type': 'table'},
#  {'title': 'timate p2 rolling garment rack free standing open wardrobe closet orga',
#   'price': '$80',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-timate-p2-rolling/7784276539.html',
#   'type': 'missing'},
#  {'title': 'metal smart box spring, mattress foundation',
#   'price': '$120',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-metal-smart-box-spring/7784272301.html',
#   'type': 'mattress'},
#  {'title': 'twin memory foam mattress and adjustable frame',
#   'price': '$250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-twin-memory-foam-mattress/7781937457.html',
#   'type': 'mattress'},
#  {'title': 'bedroom chest',
#   'price': '$80',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/stanardsville-bedroom-chest/7784127502.html',
#   'type': 'missing'},
#  {'title': 'rocking chairs',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/stanardsville-rocking-chairs/7784109737.html',
#   'type': 'chairs'},
#  {'title': 'ikea vintage desk lamp',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-ikea-vintage-desk-lamp/7784093182.html',
#   'type': 'desk'},
#  {'title': 'folding alpha chair',
#   'price': '$44',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-folding-alpha-chair/7784088106.html',
#   'type': 'chair'},
#  {'title': 'steel base and hardwood dining tables',
#   'price': '$1,800',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/orange-steel-base-and-hardwood-dining/7775307425.html',
#   'type': 'missing'},
#  {'title': 'ocean view sofa with two chairs',
#   'price': '$1,495',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ocean-view-sofa-with/7784033759.html',
#   'type': 'chairs'},
#  {'title': '1986 original nordic track exercise ski maching.',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/somerset-1986-original-nordic-track/7783995852.html',
#   'type': 'missing'},
#  {'title': 'wooden ladderback rocking chair',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/somerset-wooden-ladderback-rocking-chair/7783994794.html',
#   'type': 'chair'},
#  {'title': 'r.g.louis orginal',
#   'price': '$450',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/kents-store-rglouis-orginal/7783969146.html',
#   'type': 'missing'},
#  {'title': 'need sofa and recliner',
#   'price': '$1',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-need-sofa-and-recliner/7783935463.html',
#   'type': 'missing'},
#  {'title': 'large mahogany mirror (hardwood, made in usa)',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-large-mahogany-mirror/7783925819.html',
#   'type': 'missing'},
#  {'title': 'turbolock smart digital door lock, polished brass',
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-turbolock-smart-digital/7776226293.html',
#   'type': 'missing'},
#  {'title': 'wooden bed slat mounting kit',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-wooden-bed-slat/7776230779.html',
#   'type': 'bed'},
#  {'title': 'a room full offurniture',
#   'price': '$0',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-room-full-offurniture/7783817667.html',
#   'type': 'missing'},
#  {'title': 'beautiful side table',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/new-canton-beautiful-side-table/7782491552.html',
#   'type': 'table'},
#  {'title': 'couch',
#   'price': '$700',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-couch/7783619915.html',
#   'type': 'missing'},
#  {'title': 'beautiful clear oak table with 3 chairs',
#   'price': '$175',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-beautiful-clear-oak-table/7783591648.html',
#   'type': 'table'},
#  {'title': 'orphaned maple chair',
#   'price': '$24',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-orphaned-maple-chair/7783531652.html',
#   'type': 'chair'},
#  {'title': 'sleigh cherry wood: king bedroom',
#   'price': '$2,250',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-sleigh-cherry-wood-king/7783421438.html',
#   'type': 'missing'},
#  {'title': 'dining table with six chairs',
#   'price': '$489',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-table-with-six/7783421295.html',
#   'type': 'table'},
#  {'title': 'table lamps',
#   'price': '$10',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-table-lamps/7783388507.html',
#   'type': 'table'},
#  {'title': 'bedroom set',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-bedroom-set/7783387180.html',
#   'type': 'missing'},
#  {'title': 'claw foot hall /decorative table with drawers!',
#   'price': '$195',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-claw-foot-hall-decorative/7774390517.html',
#   'type': 'table'},
#  {'title': 'desk-for sale',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-desk-for-sale/7783315757.html',
#   'type': 'missing'},
#  {'title': 'murphy bed',
#   'price': '$1,500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/esmont-murphy-bed/7783311593.html',
#   'type': 'bed'},
#  {'title': 'cherry eurostyle desk set',
#   'price': '$700',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/ivy-cherry-eurostyle-desk-set/7783272537.html',
#   'type': 'desk'},
#  {'title': 'exquisit high end glass over bamboo table and chairs',
#   'price': '$349',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-exquisit-high-end-glass-over/7783257036.html',
#   'type': 'table'},
#  {'title': 'thomasville dresser and mirror',
#   'price': '$189',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-thomasville-dresser-and-mirror/7783252936.html',
#   'type': 'dresser'},
#  {'title': 'entertainment armoire - tv stand cabinet',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-entertainment-armoire-tv/7783250412.html',
#   'type': 'cabinet'},
#  {'title': 'wood dresser - 7 drawers',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-wood-dresser-drawers/7783238031.html',
#   'type': 'dresser'},
#  {'title': 'hutch for sale',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-hutch-for-sale/7783157927.html',
#   'type': 'hutch'},
#  {'title': 'wooden decorative cabinet',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/faber-wooden-decorative-cabinet/7783155836.html',
#   'type': 'cabinet'},
#  {'title': 'ikea laptop table/desk',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ikea-laptop-table-desk/7782958027.html',
#   'type': 'missing'},
#  {'title': 'chest of draws & night stand/tv stand',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-chest-of-draws-night/7780389275.html',
#   'type': 'missing'},
#  {'title': 'rustic farmhouse crate shelf',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-rustic-farmhouse-crate-shelf/7777518582.html',
#   'type': 'missing'},
#  {'title': 'solid wooden shoe shelf',
#   'price': '$60',
# ...
#   'price': '$30',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-window-seat-drop-leaf-table/7776896414.html',
#   'type': 'table'},
#  {'title': 'exquisite tall curio cabinet',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-exquisite-tall-curio-cabinet/7776891245.html',
#   'type': 'cabinet'},
#  {'title': 'portable kitchen storage cabinet',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-portable-kitchen-storage-cabinet/7776890701.html',
#   'type': 'cabinet'},
#  {'title': 'marble hall table',
#   'price': '$52',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-marble-hall-table/7776889273.html',
#   'type': 'table'},
#  {'title': 'lamp table',
#   'price': '$28',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-lamp-table/7776889811.html',
#   'type': 'table'},
#  {'title': '37" wrought iron wall clock',
#   'price': '$62',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-37-wrought-iron-wall-clock/7776886238.html',
#   'type': 'missing'},
#  {'title': 'beautiful milk green paint side server table',
#   'price': '$119',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-beautiful-milk-green-paint-side/7776631459.html',
#   'type': 'table'},
#  {'title': 'black wrought iron bar stools each',
#   'price': '$45',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-black-wrought-iron-bar-stools/7776627616.html',
#   'type': 'missing'},
#  {'title': 'chairs, chairs and more chairs from',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-chairs-chairs-and-more-chairs/7773853484.html',
#   'type': 'chairs'},
#  {'title': '2 matching cocktail tables',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-matching-cocktail-tables/7773852469.html',
#   'type': 'missing'},
#  {'title': 'outdoor glass top patio table and 6 chairs',
#   'price': '$99',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-outdoor-glass-top-patio-table/7773849328.html',
#   'type': 'table'},
#  {'title': 'exquisite drexel heritage corinthian collection china hutch',
#   'price': '$249',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-exquisite-drexel-heritage/7773843178.html',
#   'type': 'hutch'},
#  {'title': 'gone with the wind style lamp',
#   'price': '$65',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-gone-with-the-wind-style-lamp/7773844560.html',
#   'type': 'missing'},
#  {'title': 'dark mahogany finish end table',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-dark-mahogany-finish-end-table/7773844253.html',
#   'type': 'table'},
#  {'title': 'poplar writing/office desk',
#   'price': '$700',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-poplar-writing-office-desk/7782383790.html',
#   'type': 'desk'},
#  {'title': 'nine drawer dresser with mirror',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-nine-drawer-dresser-with/7782382805.html',
#   'type': 'dresser'},
#  {'title': 'hand crafted vintage stump chair',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-hand-crafted-vintage-stump/7775950773.html',
#   'type': 'chair'},
#  {'title': 'metal multidrawer cabinet',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-multidrawer-cabinet/7774678465.html',
#   'type': 'cabinet'},
#  {'title': 'younger furniture mid modern bantam sofa / couch',
#   'price': '$600',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-younger-furniture-mid/7774455047.html',
#   'type': 'missing'},
#  {'title': 'hamadan persian oriental rug',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-hamadan-persian-oriental-rug/7782276315.html',
#   'type': 'rug'},
#  {'title': 'desk',
#   'price': '$35',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-desk/7782254222.html',
#   'type': 'desk'},
#  {'title': 'coffee table with wheels (solid wood)',
#   'price': '$65',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-coffee-table-with/7782254089.html',
#   'type': 'table'},
#  {'title': 'antique custom built solid wood desk',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-antique-custom-built-solid-wood/7782066590.html',
#   'type': 'desk'},
#  {'title': 'leather chair',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-leather-chair/7782065696.html',
#   'type': 'chair'},
#  {'title': 'vintage country cottage foyer bench',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-vintage-country-cottage/7773461062.html',
#   'type': 'missing'},
#  {'title': 'desk',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-desk/7776427731.html',
#   'type': 'desk'},
#  {'title': 'drexel banquet server',
#   'price': '$159',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-drexel-banquet-server/7773150745.html',
#   'type': 'missing'},
#  {'title': 'mid century solid walnut oval coffee table',
#   'price': '$89',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-mid-century-solid-walnut-oval/7781762095.html',
#   'type': 'table'},
#  {'title': 'table & chairs',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-table-chairs/7781650443.html',
#   'type': 'table'},
#  {'title': 'bamboo bar stool',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-bamboo-bar-stool/7778587306.html',
#   'type': 'missing'},
#  {'title': 'for the love of blue & white chinoiserie',
#   'price': '$1,234',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-for-the-love-of-blue/7773814010.html',
#   'type': 'missing'},
#  {'title': "breakfast at tiffany's tray",
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-breakfast-at-tiffanys/7773833290.html',
#   'type': 'missing'},
#  {'title': 'vintage rattan wicker cup holders with glasses',
#   'price': '$32',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-rattan-wicker/7773869983.html',
#   'type': 'missing'},
#  {'title': 'outdoor wicker furniture',
#   'price': '$125',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-outdoor-wicker-furniture/7781469004.html',
#   'type': 'missing'},
#  {'title': 'white oak table top 2\'x2\'x1.5"',
#   'price': '$85',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-white-oak-table-top/7778801870.html',
#   'type': 'table'},
#  {'title': 'love sofa, great condition!',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/pratts-love-sofa-great-condition/7781288614.html',
#   'type': 'missing'},
#  {'title': 'beautiful chair',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-beautiful-chair/7773823328.html',
#   'type': 'chair'},
#  {'title': 'lamps',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-lamps/7777053331.html',
#   'type': 'missing'},
#  {'title': 'leather couch',
#   'price': '$0',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/shipman-leather-couch/7776510330.html',
#   'type': 'missing'},
#  {'title': 'antique brass bed',
#   'price': '$95',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-antique-brass-bed/7781080179.html',
#   'type': 'bed'},
#  {'title': 'modern farm house look in popular eggshell dining',
#   'price': '$2,175',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-modern-farm-house-look/7781037980.html',
#   'type': 'missing'},
#  {'title': 'living set includes loveseat and sofa',
#   'price': '$799',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-living-set-includes/7781037777.html',
#   'type': 'missing'},
#  {'title': 'bunk bed + bunkie board',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-bunk-bed-bunkie-board/7780921857.html',
#   'type': 'bed'},
#  {'title': 'furnitures, full queen bed set, branded single bed mattress, office chairs, and ',
#   'price': '$380',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-furnitures-full-queen/7780853617.html',
#   'type': 'bed'},
#  {'title': 'oak roll top desk with a glass door book case',
#   'price': '$269',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-oak-roll-top-desk-with-glass/7780827277.html',
#   'type': 'desk'},
#  {'title': 'corner desk',
#   'price': '$60',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-corner-desk/7780820796.html',
#   'type': 'desk'},
#  {'title': 'vessels berthing side table',
#   'price': '$65',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vessels-berthing-side/7772319022.html',
#   'type': 'table'},
#  {'title': 'regal pedestal table',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-regal-pedestal-table/7772319601.html',
#   'type': 'table'},
#  {'title': 'bakhtiari persian oriental rug',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-bakhtiari-persian-oriental-rug/7780810388.html',
#   'type': 'rug'},
#  {'title': 'ardakan persian oriental rug',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-ardakan-persian-oriental-rug/7780808355.html',
#   'type': 'rug'},
#  {'title': 'desk and hutch',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-desk-and-hutch/7780730401.html',
#   'type': 'desk'},
#  {'title': 'large bokhara oriental rug',
#   'price': '$450',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-large-bokhara-oriental-rug/7780719766.html',
#   'type': 'rug'},
#  {'title': 'filing cabinet',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-filing-cabinet/7780691936.html',
#   'type': 'cabinet'},
#  {'title': 'ikea coat rack',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ikea-coat-rack/7780690928.html',
#   'type': 'missing'},
#  {'title': 'beautiful 8x10 bokhara rug',
#   'price': '$995',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-8x10-bokhara/7780683083.html',
#   'type': 'rug'},
#  {'title': 'herman miller caper mesh chair(s)',
#   'price': '$150',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-herman-miller-caper/7772710004.html',
#   'type': 'chairs'},
#  {'title': 'afghan wool oriental rug runner',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-afghan-wool-oriental-rug/7780615896.html',
#   'type': 'rug'},
#  {'title': 'end table',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lovingston-end-table/7780611962.html',
#   'type': 'table'},
#  {'title': 'west elm henry sofa 76"',
#   'price': '$700',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-west-elm-henry-sofa-76/7780602090.html',
#   'type': 'missing'},
#  {'title': 'moud persian oriental rug',
#   'price': '$500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-moud-persian-oriental-rug/7780591378.html',
#   'type': 'rug'},
#  {'title': 'qashqai persian oriental rug runner',
#   'price': '$350',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-qashqai-persian-oriental-rug/7780589339.html',
#   'type': 'rug'},
#  {'title': 'afghan balouch oriental rug',
#   'price': '$300',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-afghan-balouch-oriental-rug/7780586695.html',
#   'type': 'rug'},
#  {'title': 'wheelchair',
#   'price': '$75',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/rocky-mount-wheelchair/7780584116.html',
#   'type': 'missing'},
#  {'title': 'arak persian oriental rug runner',
#   'price': '$400',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-arak-persian-oriental-rug/7780575391.html',
#   'type': 'rug'},
#  {'title': 'drexel heritage dining table',
#   'price': '$500',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/rocky-mount-drexel-heritage-dining-table/7779829760.html',
#   'type': 'table'},
#  {'title': 'joybird couch',
#   'price': '$800',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-joybird-couch/7780558678.html',
#   'type': 'missing'},
#  {'title': 'yard sale signs',
#   'price': '$25',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-yard-sale-signs/7780544573.html',
#   'type': 'missing'},
#  {'title': 'chairs',
#   'price': '$1',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-chairs/7780543594.html',
#   'type': 'chairs'},
#  {'title': 'twin size day bed with trundle bed',
#   'price': '$200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-twin-size-day-bed-with/7771732883.html',
#   'type': 'bed'},
#  {'title': 'wooden arm chairs',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lovingston-wooden-arm-chairs/7780480496.html',
#   'type': 'chairs'},
#  {'title': 'wooden arm chairs',
#   'price': '$15',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lovingston-wooden-arm-chairs/7780480364.html',
#   'type': 'chairs'},
#  {'title': 'wooden blue bookshelf',
#   'price': '$20',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-wooden-blue-bookshelf/7774578321.html',
#   'type': 'missing'},
#  {'title': 'furniture for sale',
#   'price': '$1',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keswick-furniture-for-sale/7780382720.html',
#   'type': 'missing'},
#  {'title': 'recliner + other items',
#   'price': '$35',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/afton-recliner-other-items/7780348890.html',
#   'type': 'missing'},
#  {'title': 'bookshelf',
#   'price': '$100',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/kents-store-bookshelf/7774617860.html',
#   'type': 'missing'},
#  {'title': 'lazy boy recliner',
#   'price': '$80',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-lazy-boy-recliner/7780259559.html',
#   'type': 'missing'},
#  {'title': 'dining outdoor furniture set',
#   'price': '$895',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-outdoor/7780104001.html',
#   'type': 'missing'},
#  {'title': 'large chaise sectional light charcoal',
#   'price': '$555',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-large-chaise-sectional/7780102341.html',
#   'type': 'missing'},
#  {'title': 'table, "this end up" brand',
#   'price': '$9',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-table-this-end-up-brand/7776030712.html',
#   'type': 'table'},
#  {'title': 'high-grade faux leather blue couch and loveseat',
#   'price': '$750',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-high-grade-faux-leather/7780075087.html',
#   'type': 'missing'},
#  {'title': 'ashley coralayne king sleigh bed with dresser and 2 night stands',
#   'price': '$1,200',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keswick-ashley-coralayne-king-sleigh/7780067926.html',
#   'type': 'bed'},
#  {'title': 'black faux leather arm chair',
#   'price': '$110',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-black-faux-leather-arm/7780064371.html',
#   'type': 'chair'},
#  {'title': 'beautifull solid wood game table 30" h x 24" h',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-beautifull-solid-wood-game/7780061213.html',
#   'type': 'table'},
#  {'title': 'desks, desks, desks starting at',
#   'price': '$50',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-desks-desks-desks-starting-at/7780060820.html',
#   'type': 'desks'},
#  {'title': 'oriental rug by safavieh (11\'9" x 8\'9")',
#   'price': '$39',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-oriental-rug-by-safavieh-119-89/7780060317.html',
#   'type': 'rug'}]

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (102, 6)
#                                                title  price    year  \
# 0                                2008 subaru impreza   2000  2008.0
# 1  2018 tesla model 3 mid range or 2018 tesla mod...  16900  2018.0
# 2                      2010 lexus is250c convertible  14950  2010.0
# 3                           2010 chevy malibu 4-door    800  2010.0
# 4                                             bmw x5   8500     NaN
#
#                                                 link   brand   age
# 0  https://charlottesville.craigslist.org/cto/d/c...  subaru  17.0
# 1  https://charlottesville.craigslist.org/cto/d/h...   tesla   7.0
# 2  https://charlottesville.craigslist.org/cto/d/c...   lexus  15.0
# 3  https://charlottesville.craigslist.org/cto/d/p...   chevy  15.0
# 4  https://charlottesville.craigslist.org/cto/d/w...     bmw   NaN

# %%
## Wrangle the data
fdf = pd.DataFrame.from_dict(furniture_data)
fdf['price'] = fdf['price'].str.replace('$','')
fdf['price'] = fdf['price'].str.replace(',','')
fdf['price'] = pd.to_numeric(fdf['price'],errors='coerce')

fdf['type'] = fdf['type'].replace({'chairs': 'chair'})
fdf['type'] = fdf['type'].replace({'nightstands': 'nightstand'})
fdf['type'] = fdf['type'].replace({'desks': 'desk'})


print(fdf.shape)
df.to_csv('craigslist_cville_furniture.csv') # Save data in case of a disaster
fdf.head()
# Out:
# (357, 4)
#                                      title  price  \
# 0  west elm lena mid-century dining chairs    450
# 1             leather/wood foldable chair!     95
# 2                 solid wood accent table!     95
# 3  queen mattress & box spring! brand new!    350
# 4                              china hutch     49
#
#                                                 link      type
# 0  https://charlottesville.craigslist.org/fuo/d/p...     chair
# 1  https://charlottesville.craigslist.org/fuo/d/b...     chair
# 2  https://charlottesville.craigslist.org/fuo/d/b...     table
# 3  https://charlottesville.craigslist.org/fuo/d/b...  mattress
# 4  https://charlottesville.craigslist.org/fuo/d/b...     hutch

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count      102.000000
# mean      7913.470588
# std       7571.052098
# min         10.000000
# 25%       3000.000000
# 50%       5000.000000
# 75%      10000.000000
# max      38000.000000
# Name: price, dtype: float64
# count    81.000000
# mean     20.790123
# std      12.624100
# min       4.000000
# 25%      14.000000
# 50%      18.000000
# 75%      23.000000
# max      67.000000
# Name: age, dtype: float64

# %%
# EDA for price and age:
print(fdf['price'].describe())
fdf['price'].hist(grid=False)
plt.title("EDA for furniture prices")
plt.show()
# Out:
# count     357.000000
# mean      223.946779
# std       479.487665
# min         0.000000
# 25%        30.000000
# 50%        75.000000
# 75%       200.000000
# max      4800.000000
# Name: price, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# acura        1.0   3500.000000           NaN   3500.0   3500.00   3500.0
# audi         2.0   6432.500000   7399.872465   1200.0   3816.25   6432.5
# bmw          4.0   5850.000000   2248.703330   3000.0   5175.00   5950.0
# buick        2.0   4250.000000    353.553391   4000.0   4125.00   4250.0
# chevrolet    4.0   8750.000000   5866.571969   5000.0   5750.00   6250.0
# chevy        7.0   2330.000000   1726.644144     10.0    900.00   2500.0
# dodge        5.0   5740.000000   3080.259729   2000.0   3700.00   6000.0
# ford         8.0   7806.250000   5888.999278   1000.0   3000.00   7775.0
# gmc          4.0   5712.500000   2424.312617   3500.0   4025.00   5225.0
# honda       10.0   7164.900000   3914.201790   1000.0   4775.00   7200.0
# jeep         4.0   9000.000000   8256.310718   1500.0   2625.00   7750.0
# kia          2.0   6500.000000   4242.640687   3500.0   5000.00   6500.0
# lexus        1.0  14950.000000           NaN  14950.0  14950.00  14950.0
# missing     28.0   9292.857143   8969.513326   1200.0   2775.00   5225.0
# mitsubishi   1.0   3200.000000           NaN   3200.0   3200.00   3200.0
# subaru       6.0   7200.000000   7534.719636   2000.0   2750.00   4650.0
# tesla        2.0  21450.000000   6434.671709  16900.0  19175.00  21450.0
# toyota       8.0  12431.250000  13941.022137   1500.0   3450.00   5800.0
# volkswagen   1.0   4950.000000           NaN   4950.0   4950.00   4950.0
# volvo        2.0   2050.000000     70.710678   2000.0   2025.00   2050.0
#
#
#                  75%      max
# brand
# acura        3500.00   3500.0
# audi         9048.75  11665.0
# bmw          6625.00   8500.0
# buick        4375.00   4500.0
# chevrolet    9250.00  17500.0
# chevy        4000.00   4000.0
# dodge        7000.00  10000.0
# ford        11050.00  18500.0
# gmc          6912.50   8900.0
# honda        9637.50  13000.0
# jeep        14125.00  19000.0
# kia          8000.00   9500.0
# lexus       14950.00  14950.0
# missing     15000.00  31950.0
# mitsubishi   3200.00   3200.0
# subaru       7000.00  22000.0
# tesla       23725.00  26000.0
# toyota      15887.50  38000.0
# volkswagen   4950.00   4950.0
# volvo        2075.00   2100.0

# %%
# Price by furniture type:
fdf.loc[:,['price','type']].groupby('type').describe()
# Out:
#             price
#             count        mean         std   min    25%    50%     75%     max
# type
# bed          17.0  363.529412  423.485407  10.0  150.0  200.0  350.00  1500.0
# cabinet      15.0  110.600000  181.518515  20.0   20.0   39.0   87.50   700.0
# chair        46.0  123.891304  235.810963   1.0   20.0   44.5  140.00  1495.0
# desk         27.0  150.074074  220.803415  10.0   20.0   50.0  175.00   750.0
# dresser       5.0   92.800000   72.434108  25.0   40.0   60.0  150.00   189.0
# hutch         3.0  116.000000  115.182464  49.0   49.5   50.0  149.50   249.0
# mattress      8.0  175.000000  124.096736  30.0  100.0  110.0  275.00   350.0
# missing     157.0  242.229299  514.952884   0.0   25.0   65.0  150.00  3600.0
# nightstand    1.0   39.000000         NaN  39.0   39.0   39.0   39.00    39.0
# rug          17.0  415.823529  347.204413  39.0  300.0  350.0  400.00  1500.0
# shelving      1.0   75.000000         NaN  75.0   75.0   75.0   75.00    75.0
# table        60.0  248.900000  704.117183   9.0   39.0   76.5  131.25  4800.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min    25%   50%    75%   max
# brand
# acura        1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# audi         1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# bmw          2.0  12.500000   2.121320  11.0  11.75  12.5  13.25  14.0
# buick        0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN
# chevrolet    4.0  29.500000   8.962886  17.0  26.00  32.5  36.00  36.0
# chevy        6.0  23.666667   5.465040  15.0  21.50  24.0  26.50  31.0
# dodge        1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# ford         7.0  28.285714  19.006265  13.0  17.50  20.0  31.50  67.0
# gmc          4.0  19.500000   7.325754  10.0  16.00  20.5  24.00  27.0
# honda       10.0  17.000000   7.180220  10.0  11.25  15.5  20.50  33.0
# jeep         3.0  37.333333  22.368132  22.0  24.50  27.0  45.00  63.0
# kia          2.0  12.500000   4.949747   9.0  10.75  12.5  14.25  16.0
# lexus        1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# missing     20.0  22.300000  16.085626   6.0  14.75  18.0  21.75  62.0
# mitsubishi   1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# subaru       6.0  15.000000   4.335897   7.0  14.00  17.0  17.75  18.0
# tesla        2.0   8.000000   1.414214   7.0   7.50   8.0   8.50   9.0
# toyota       7.0  14.571429   8.695921   4.0   7.00  17.0  20.00  27.0
# volkswagen   1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# volvo        2.0  27.000000   8.485281  21.0  24.00  27.0  30.00  33.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   1.173049 -0.173887
# log_age    -0.173887  0.304558
#            log_price   log_age
# log_price   1.000000 -0.333344
# log_age    -0.333344  1.000000

# %%
mean_price_by_type_ascending = fdf.groupby('type')['price'].mean().reset_index().sort_values(by='price')

sns.barplot(x='type', y='price', data=mean_price_by_type_ascending)
plt.title('Average Price by Furniture Type')
plt.xlabel('Furniture Type')
plt.xticks(rotation=45)
plt.ylabel('Average Price ($)')
plt.show()

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 4. (Optional) From your search results, crawl to the links and extract more information about every listing in your original dataframe. Wrangle and do some EDA.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #
    try:
        year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
    except:
        year_post = np.nan
    #
    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'
    #
    try:
        cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
        cylinders = cylinders.replace('\n','')
    except:
        cylinders = 'missing'
    #
    try:
        drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
    except:
        drivetrain = 'missing'
    #
    try:
        fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
    except:
        fuel = 'missing'
    #
    try:
        miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
    except:
        miles = np.nan
    #
    try:
        color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
    except:
        color='missing'
    #
    try:
        title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
    except:
        title='missing'
    #
    try:
        transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
    except:
        transmission = 'missing'
    #
    try:
        bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
    except:
        bodytype = 'missing'
    #
    text = bsObj.find(id='postingbody').get_text()
    text = text.replace('\n','')
    text = text.replace('QR Code Link to This Post','')
    record = {'title':title,
              'year_post':year_post,
              'condition':condition,
              'cylinders':cylinders,
              'drivetrain':drivetrain,
              'fuel':fuel,
              'miles':miles,
              'color':color,
              'title':'title',
              'transmission':transmission,
              'bodytype':bodytype,
              'text':text,}
    data.append(record)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/evaterry/Desktop/DS 3001/labs/02_scraping/lab_notebook.ipynb Cell 23 line 7
#       <a href='vscode-notebook-cell:/Users/evaterry/Desktop/DS%203001/labs/02_scraping/lab_notebook.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> data = []
#       <a href='vscode-notebook-cell:/Users/evaterry/Desktop/DS%203001/labs/02_scraping/lab_notebook.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a> for link in links: # about 3 minutes
# ----> <a href='vscode-notebook-cell:/Users/evaterry/Desktop/DS%203001/labs/02_scraping/lab_notebook.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a>     time.sleep(random.randint(1, 3)) # Random delays
#       <a href='vscode-notebook-cell:/Users/evaterry/Desktop/DS%203001/labs/02_scraping/lab_notebook.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a>     raw = requests.get(link,headers=header) # Get page
#       <a href='vscode-notebook-cell:/Users/evaterry/Desktop/DS%203001/labs/02_scraping/lab_notebook.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a>     bsObj = soup(raw.content,'html.parser') # Parse the html
#
# KeyboardInterrupt:

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()

df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df['miles'] = df['miles'].str.replace(',','')
df['miles'] = pd.to_numeric(df['miles'],errors='coerce')

df['year_post'] = df['year_post'].str.replace(',','')
df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
df.to_csv('craiglist_cville_cars_long.csv')
